# %% [markdown]
# <a href="https://colab.research.google.com/github/joaofernandesw/yolo-vehicle-detection/blob/main/YOLO_deteccao_carros.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Fri Aug 22 17:46:42 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install opendatasets

# %%
import opendatasets as op

op.download('https://www.kaggle.com/datasets/alkanerturan/vehicledetection')
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: joaofernandesw
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/alkanerturan/vehicledetection
# ...
# 100%|██████████| 62.8M/62.8M [00:00<00:00, 1.35GB/s]

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 66.0 MB/s eta 0:00:00
# ...

# %%
# !yolo detect train data=/content/vehicledetection/VehiclesDetectionDataset/dataset.yaml model=yolov8n epochs=100 imgsz=640 patience=20
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.184 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO('runs/detect/train/weights/best.pt')

results = model.predict(source='/content/vehicledetection/TestVideo/TrafficPolice.mp4', save=True)
print("Detecção concluída! O vídeo foi salvo na pasta 'runs/detect/predict'.")
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/2362) /content/vehicledetection/TestVideo/TrafficPolice.mp4: 384x640 7 Cars, 52.9ms
# video 1/1 (frame 2/2362) /content/vehicledetection/TestVideo/TrafficPolice.mp4: 384x640 7 Cars, 7.2ms
# video 1/1 (frame 3/2362) /content/vehicledetection/TestVideo/TrafficPolice.mp4: 384x640 9 Cars, 7.9ms
# video 1/1 (frame 4/2362) /content/vehicledetection/TestVideo/TrafficPolice.mp4: 384x640 9 Cars, 7.6ms
# ...
